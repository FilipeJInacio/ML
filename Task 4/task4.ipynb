# %% [markdown]
# ### **Imports Made**:
# - Numpy for general purpose tasks (ex: file loads, matrix operations and arrangements, etc)
# - TensorFlow for the entire CNN structure and implementation, as well as a multitude of additional general purpose functions regarding machine learning and transfer learning models used like Inception V3
# - sklearn.model_selection for the train test split function that allows our data split
# - sklearn.linear_metrics for more precise accuracy indicators, and confusion matrix representation
# - sklearn.utils for the shuffle function, that will shuffle the augmented data
# - Random Set Seeds to created a deterministic environment for weight assignements and random calculations
#
#
# The key metric to be evaluated will be Balanced Accuracy, just as stated in the project report.

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, balanced_accuracy_score
from sklearn.utils import shuffle
from numpy import random

np.random.seed(2)

tf.random.set_seed(57)

# %%
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module="sklearn.metrics._classification")


def balanced_accuracy(y_true, y_pred):
    y_pred = tf.argmax(y_pred, axis=1)
    y_true = tf.argmax(y_true, axis=1)
    return tf.py_function(balanced_accuracy_score, (y_true, y_pred), tf.float32)

augmented_class2 = []
augmented_class3 = []
augmented_class4 = []
augmented_class5 = []
augmented_class6 = []

x = np.load("Xtrain_Classification2.npy")
y = np.load("ytrain_Classification2.npy")
x_test = np.load("Xtest_Classification2.npy")

print(x.shape)

print(y.shape)

print(x_test.shape)

n_class1 = len([0 for i in range(y.shape[0]) if y[i] == 0])
n_class2 = len([0 for i in range(y.shape[0]) if y[i] == 1])
n_class3 = len([0 for i in range(y.shape[0]) if y[i] == 2])
n_class4 = len([0 for i in range(y.shape[0]) if y[i] == 3])
n_class5 = len([0 for i in range(y.shape[0]) if y[i] == 4])
n_class6 = len([0 for i in range(y.shape[0]) if y[i] == 5])

print(f'Class 1 is {(n_class1/(n_class1 + n_class2 + n_class3 + n_class4 + n_class5 + n_class6)) * 100}% of the data set')
print(f'Class 2 is {(n_class2/(n_class1 + n_class2 + n_class3 + n_class4 + n_class5 + n_class6)) * 100}% of the data set')
print(f'Class 3 is {(n_class3/(n_class1 + n_class2 + n_class3 + n_class4 + n_class5 + n_class6)) * 100}% of the data set')
print(f'Class 4 is {(n_class4/(n_class1 + n_class2 + n_class3 + n_class4 + n_class5 + n_class6)) * 100}% of the data set')
print(f'Class 5 is {(n_class5/(n_class1 + n_class2 + n_class3 + n_class4 + n_class5 + n_class6)) * 100}% of the data set')
print(f'Class 6 is {(n_class6/(n_class1 + n_class2 + n_class3 + n_class4 + n_class5 + n_class6)) * 100}% of the data set')

x = np.reshape(x,(len(x),28,28,3))

x = (x).astype('float32')/255.0

x_test = np.reshape(x_test,(len(x_test),28,28,3))

x_test = (x_test).astype('float32')/255.0

print(x.shape)

X_train, X_val, y_train, y_val = train_test_split(x, y, stratify = y,test_size = 0.2)

n_class1t = len([0 for i in range(y_train.shape[0]) if y_train[i] == 0])
n_class2t = len([0 for i in range(y_train.shape[0]) if y_train[i] == 1])
n_class3t = len([0 for i in range(y_train.shape[0]) if y_train[i] == 2])
n_class4t = len([0 for i in range(y_train.shape[0]) if y_train[i] == 3])
n_class5t = len([0 for i in range(y_train.shape[0]) if y_train[i] == 4])
n_class6t = len([0 for i in range(y_train.shape[0]) if y_train[i] == 5])

print(f'Class 1 is {(n_class1t/(n_class1t + n_class2t + n_class3t + n_class4t + n_class5t + n_class6t)) * 100}% of the train data set')
print(f'Class 2 is {(n_class2t/(n_class1t + n_class2t + n_class3t + n_class4t + n_class5t + n_class6t)) * 100}% of the train data set')
print(f'Class 3 is {(n_class3t/(n_class1t + n_class2t + n_class3t + n_class4t + n_class5t + n_class6t)) * 100}% of the train data set')
print(f'Class 4 is {(n_class4t/(n_class1t + n_class2t + n_class3t + n_class4t + n_class5t + n_class6t)) * 100}% of the train data set')
print(f'Class 5 is {(n_class5t/(n_class1t + n_class2t + n_class3t + n_class4t + n_class5t + n_class6t)) * 100}% of the train data set')
print(f'Class 6 is {(n_class6t/(n_class1t + n_class2t + n_class3t + n_class4t + n_class5t + n_class6t)) * 100}% of the train data set \n')

n_class1v = len([0 for i in range(y_val.shape[0]) if y_val[i] == 0])
n_class2v = len([0 for i in range(y_val.shape[0]) if y_val[i] == 1])
n_class3v = len([0 for i in range(y_val.shape[0]) if y_val[i] == 2])
n_class4v = len([0 for i in range(y_val.shape[0]) if y_val[i] == 3])
n_class5v = len([0 for i in range(y_val.shape[0]) if y_val[i] == 4])
n_class6v = len([0 for i in range(y_val.shape[0]) if y_val[i] == 5])

print(f'Class 1 is {(n_class1v/(n_class1v + n_class2v + n_class3v + n_class4v + n_class5v + n_class6v)) * 100}% of the validation data set')
print(f'Class 2 is {(n_class2v/(n_class1v + n_class2v + n_class3v + n_class4v + n_class5v + n_class6v)) * 100}% of the validation data set')
print(f'Class 3 is {(n_class3v/(n_class1v + n_class2v + n_class3v + n_class4v + n_class5v + n_class6v)) * 100}% of the validation data set')
print(f'Class 4 is {(n_class4v/(n_class1v + n_class2v + n_class3v + n_class4v + n_class5v + n_class6v)) * 100}% of the validation data set')
print(f'Class 5 is {(n_class5v/(n_class1v + n_class2v + n_class3v + n_class4v + n_class5v + n_class6v)) * 100}% of the validation data set')
print(f'Class 6 is {(n_class6v/(n_class1v + n_class2v + n_class3v + n_class4v + n_class5v + n_class6v)) * 100}% of the validation data set')

class1 = X_train[y_train == 0]
class2 = X_train[y_train == 1]
class3 = X_train[y_train == 2]
class4 = X_train[y_train == 3]
class5 = X_train[y_train == 4]
class6 = X_train[y_train == 5]
# Out:
# (10629, 2352)
# (10629,)
# (2658, 2352)
# Class 1 is 50.44689058236899% of the data set
# Class 2 is 8.373318280176875% of the data set
# Class 3 is 1.0913538432590084% of the data set
# Class 4 is 21.685953523379435% of the data set
# Class 5 is 9.314140558848434% of the data set
# Class 6 is 9.08834321196726% of the data set
# (10629, 28, 28, 3)
# Class 1 is 50.44102081618252% of the train data set
# Class 2 is 8.373515229918853% of the train data set
# Class 3 is 1.0937316241326591% of the train data set
# Class 4 is 21.68646360108197% of the train data set
# Class 5 is 9.314359637774903% of the train data set
# Class 6 is 9.090909090909092% of the train data set
#
# Class 1 is 50.47036688617121% of the validation data set
# Class 2 is 8.372530573847602% of the validation data set
# Class 3 is 1.0818438381937912% of the validation data set
# Class 4 is 21.683913452492945% of the validation data set
# Class 5 is 9.313264346190028% of the validation data set
# Class 6 is 9.078080903104421% of the validation data set

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.5),
])

for i in range(n_class1t - n_class2t):
    random_index = np.random.randint(0, n_class2t)
    augmented_image = data_augmentation(tf.expand_dims(class2[random_index], 0))
    augmented_class2.append(augmented_image)

augmented_class2 = np.vstack(augmented_class2)

X_train_balanced = np.vstack([X_train, augmented_class2])
y_train_balanced = np.concatenate([y_train, np.ones(n_class1t - n_class2t)])

for i in range(n_class1t - n_class3t):
    random_index = np.random.randint(0, n_class3t)
    augmented_image = data_augmentation(tf.expand_dims(class3[random_index], 0))
    augmented_class3.append(augmented_image)

augmented_class3 = np.vstack(augmented_class3)

X_train_balanced = np.vstack([X_train_balanced, augmented_class3])
y_train_balanced = np.concatenate([y_train_balanced, 2*np.ones(n_class1t - n_class3t)])

for i in range(n_class1t - n_class4t):
    random_index = np.random.randint(0, n_class4t)
    augmented_image = data_augmentation(tf.expand_dims(class4[random_index], 0))
    augmented_class4.append(augmented_image)

augmented_class4 = np.vstack(augmented_class4)

X_train_balanced = np.vstack([X_train_balanced, augmented_class4])
y_train_balanced = np.concatenate([y_train_balanced, 3*np.ones(n_class1t - n_class4t)])

for i in range(n_class1t - n_class5t):
    random_index = np.random.randint(0, n_class5t)
    augmented_image = data_augmentation(tf.expand_dims(class5[random_index], 0))
    augmented_class5.append(augmented_image)

augmented_class5 = np.vstack(augmented_class5)

X_train_balanced = np.vstack([X_train_balanced, augmented_class5])
y_train_balanced = np.concatenate([y_train_balanced, 4*np.ones(n_class1t - n_class5t)])

for i in range(n_class1t - n_class6t):
    random_index = np.random.randint(0, n_class6t)
    augmented_image = data_augmentation(tf.expand_dims(class6[random_index], 0))
    augmented_class6.append(augmented_image)

augmented_class6 = np.vstack(augmented_class6)

X_train_balanced = np.vstack([X_train_balanced, augmented_class6])
y_train_balanced = np.concatenate([y_train_balanced, 5*np.ones(n_class1t - n_class6t)])

# %%
n_class1a = len([0 for i in range(y_train_balanced.shape[0]) if y_train_balanced[i] == 0])
n_class2a = len([0 for i in range(y_train_balanced.shape[0]) if y_train_balanced[i] == 1])
n_class3a = len([0 for i in range(y_train_balanced.shape[0]) if y_train_balanced[i] == 2])
n_class4a = len([0 for i in range(y_train_balanced.shape[0]) if y_train_balanced[i] == 3])
n_class5a = len([0 for i in range(y_train_balanced.shape[0]) if y_train_balanced[i] == 4])
n_class6a = len([0 for i in range(y_train_balanced.shape[0]) if y_train_balanced[i] == 5])

print(f'Class 1 is {(n_class1a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')
print(f'Class 2 is {(n_class2a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')
print(f'Class 3 is {(n_class3a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')
print(f'Class 4 is {(n_class4a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')
print(f'Class 5 is {(n_class5a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')
print(f'Class 6 is {(n_class6a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')

X_train_balanced_shuffled, y_train_balanced_shuffled = shuffle(X_train_balanced, y_train_balanced, random_state=0)

y_train_balanced_c = tf.keras.utils.to_categorical(y_train_balanced_shuffled,6)
y_val_c = tf.keras.utils.to_categorical(y_val,6)
# Out:
# Class 1 is 16.666666666666664% of the balanced data set
# Class 2 is 16.666666666666664% of the balanced data set
# Class 3 is 16.666666666666664% of the balanced data set
# Class 4 is 16.666666666666664% of the balanced data set
# Class 5 is 16.666666666666664% of the balanced data set
# Class 6 is 16.666666666666664% of the balanced data set

# %% [markdown]
# ## **Convolutional Neural Network**:
#
# The model consists of a sequence of initial convolutional layers, especialized to provide and recongnize numerous patterns and features within the image, and this information is then subsequently processed and repurposed through our use of Dropout layers in between each MaxPooling2D, and finally a BatchNormalization layer in the MLP section followed by a Dropout layer of considerable intesity (0.7). Throughout testing with the CNN hyperparameter tuning this model proved to be the one most efficient in providing the least validation loss in our data, along with a relatively high batch size of 1000 that allows the stabilization of validation loss improvement while training. 100 epochs allows (in the graph plotted in the end of the section) full view of validation loss behaviours during the training process, most notably allowing the observation of plateau zones. This added with an early stopping callback implemented to return to the weights of the sequence with the lowest validation loss provides our training with a very thorough and careful approach to determine the best possible weight configuration.
#
# Finally after the best weight structure is assigned, the balanced accuracy of the validation set is externally calculated and it's confusion matrix is displayed.

# %%
batch_size = 1000
lr = 0.001
epochs = 100

model_MLP = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(28, 28, 3)),
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.7),
    tf.keras.layers.Dense(6, activation='softmax')
])

model_MLP.summary()

adam = tf.keras.optimizers.Adam(learning_rate = lr)
model_MLP.compile(optimizer = adam,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy', balanced_accuracy])

early_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_balanced_accuracy', patience = 20, verbose = 1, restore_best_weights = True)

history = model_MLP.fit(x = X_train_balanced_shuffled, y = y_train_balanced_c, epochs = epochs, batch_size = batch_size, validation_data = (X_val,y_val_c), callbacks = [early_callback])

y_pred = model_MLP.predict(X_val)
y_pred = np.argmax(y_pred, axis = 1)
model_MLP.evaluate(X_val, y_val_c)
y_true = np.argmax(y_val_c, axis = 1)
print(f'Balanced Accuracy score is {balanced_accuracy_score(y_true, y_pred)}')


####PLOT EVOLUTION
plt.figure(1)
plt.clf()
plt.plot(history.history['loss'], label = 'train', color = "blue", linewidth = 3, alpha = 0.6)
plt.plot(history.history['val_loss'], label = 'validation', color = "green", linewidth = 3, alpha = 0.6)
plt.xlabel(r"Epochs")
plt.ylabel(r"Loss")
plt.title(r"CNN Evaluation", fontsize = 14)
plt.legend(labels=[r'Train', r'Validation'])
plt.grid(linestyle = '--', alpha = 0.5)
plt.show()

cm = confusion_matrix(y_true, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 26, 26, 32)        896
#
#  conv2d_16 (Conv2D)          (None, 24, 24, 32)        9248
#
#  conv2d_17 (Conv2D)          (None, 22, 22, 32)        9248
#
#  max_pooling2d_9 (MaxPooling  (None, 11, 11, 32)       0
#  2D)
#
#  dropout_12 (Dropout)        (None, 11, 11, 32)        0
#
#  conv2d_18 (Conv2D)          (None, 9, 9, 64)          18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 4, 4, 64)          0
#
#  conv2d_19 (Conv2D)          (None, 2, 2, 128)         73856
#
#  max_pooling2d_11 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_3 (Flatten)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_7 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 120,646
# Trainable params: 120,518
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 2s 47ms/step - loss: 1.5538 - accuracy: 0.3391 - balanced_accuracy: 0.3410 - val_loss: 1.7256 - val_accuracy: 0.5833 - val_balanced_accuracy: 0.3946
# Epoch 2/100
# 26/26 [==============================] - 1s 40ms/step - loss: 1.0589 - accuracy: 0.5197 - balanced_accuracy: 0.5208 - val_loss: 1.6736 - val_accuracy: 0.5936 - val_balanced_accuracy: 0.5395
# Epoch 3/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.8849 - accuracy: 0.6182 - balanced_accuracy: 0.6189 - val_loss: 1.6074 - val_accuracy: 0.6726 - val_balanced_accuracy: 0.5709
# Epoch 4/100
# 26/26 [==============================] - 1s 39ms/step - loss: 0.7755 - accuracy: 0.6763 - balanced_accuracy: 0.6769 - val_loss: 1.5539 - val_accuracy: 0.7554 - val_balanced_accuracy: 0.6226
# Epoch 5/100
# 26/26 [==============================] - 1s 39ms/step - loss: 0.7058 - accuracy: 0.7107 - balanced_accuracy: 0.7111 - val_loss: 1.4860 - val_accuracy: 0.7836 - val_balanced_accuracy: 0.6770
# Epoch 6/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6605 - accuracy: 0.7388 - balanced_accuracy: 0.7397 - val_loss: 1.4477 - val_accuracy: 0.7333 - val_balanced_accuracy: 0.7797
# Epoch 7/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6101 - accuracy: 0.7587 - balanced_accuracy: 0.7590 - val_loss: 1.3008 - val_accuracy: 0.7808 - val_balanced_accuracy: 0.7645
# Epoch 8/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.5793 - accuracy: 0.7754 - balanced_accuracy: 0.7762 - val_loss: 1.2393 - val_accuracy: 0.7719 - val_balanced_accuracy: 0.7752
# Epoch 9/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.5289 - accuracy: 0.7929 - balanced_accuracy: 0.7931 - val_loss: 1.1531 - val_accuracy: 0.7554 - val_balanced_accuracy: 0.8364
# Epoch 10/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.5040 - accuracy: 0.8035 - balanced_accuracy: 0.8038 - val_loss: 1.1136 - val_accuracy: 0.7516 - val_balanced_accuracy: 0.8271
# Epoch 11/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.4765 - accuracy: 0.8143 - balanced_accuracy: 0.8147 - val_loss: 1.0041 - val_accuracy: 0.7940 - val_balanced_accuracy: 0.8430
# Epoch 12/100
# 26/26 [==============================] - 1s 41ms/step - loss: 0.4508 - accuracy: 0.8269 - balanced_accuracy: 0.8273 - val_loss: 0.8466 - val_accuracy: 0.7658 - val_balanced_accuracy: 0.8247
# Epoch 13/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.4326 - accuracy: 0.8341 - balanced_accuracy: 0.8340 - val_loss: 0.7971 - val_accuracy: 0.7799 - val_balanced_accuracy: 0.8254
# Epoch 14/100
# 26/26 [==============================] - 1s 39ms/step - loss: 0.4134 - accuracy: 0.8410 - balanced_accuracy: 0.8412 - val_loss: 0.7599 - val_accuracy: 0.7705 - val_balanced_accuracy: 0.8006
# Epoch 15/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0
100
# 26/26 [==============================] - 1s 39ms/step - loss: 0.2302 - accuracy: 0.9087 - balanced_accuracy: 0.9091 - val_loss: 0.3216 - val_accuracy: 0.8410 - val_balanced_accuracy: 0.8759
# Epoch 53/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2224 - accuracy: 0.9107 - balanced_accuracy: 0.9109 - val_loss: 0.3120 - val_accuracy: 0.8335 - val_balanced_accuracy: 0.8878
# Epoch 54/100
# 26/26 [==============================] - 1s 39ms/step - loss: 0.2127 - accuracy: 0.9146 - balanced_accuracy: 0.9149 - val_loss: 0.3084 - val_accuracy: 0.8297 - val_balanced_accuracy: 0.8691
# Epoch 55/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2182 - accuracy: 0.9137 - balanced_accuracy: 0.9141 - val_loss: 0.3330 - val_accuracy: 0.8368 - val_balanced_accuracy: 0.8943
# Epoch 56/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2145 - accuracy: 0.9158 - balanced_accuracy: 0.9161 - val_loss: 0.2941 - val_accuracy: 0.8504 - val_balanced_accuracy: 0.8823
# Epoch 57/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2016 - accuracy: 0.9189 - balanced_accuracy: 0.9189 - val_loss: 0.3091 - val_accuracy: 0.8358 - val_balanced_accuracy: 0.8860
# Epoch 58/100
# 26/26 [==============================] - 1s 39ms/step - loss: 0.1979 - accuracy: 0.9208 - balanced_accuracy: 0.9211 - val_loss: 0.3273 - val_accuracy: 0.8330 - val_balanced_accuracy: 0.8879
# Epoch 59/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2120 - accuracy: 0.9147 - balanced_accuracy: 0.9146 - val_loss: 0.2992 - val_accuracy: 0.8500 - val_balanced_accuracy: 0.8506
# Epoch 60/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2122 - accuracy: 0.9170 - balanced_accuracy: 0.9173 - val_loss: 0.3552 - val_accuracy: 0.8354 - val_balanced_accuracy: 0.8878
# Epoch 61/100
# 26/26 [==============================] - 1s 39ms/step - loss: 0.2067 - accuracy: 0.9180 - balanced_accuracy: 0.9183 - val_loss: 0.2842 - val_accuracy: 0.8758 - val_balanced_accuracy: 0.8438
# Epoch 62/100
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2095 - accuracy: 0.9172 - balanced_accuracy: 0.9178 - val_loss: 0.3330 - val_accuracy: 0.8133 - val_balanced_accuracy: 0.8799
# Epoch 63/100
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1972 - accuracy: 0.9197 - balanced_accuracy: 0.9197Restoring model weights from the end of the best epoch: 43.
# 26/26 [==============================] - 1s 39ms/step - loss: 0.1968 - accuracy: 0.9201 - balanced_accuracy: 0.9202 - val_loss: 0.3503 - val_accuracy: 0.8161 - val_balanced_accuracy: 0.8800
# Epoch 63: early stopping
# 67/67 [==============================] - 0s 6ms/step - loss: 0.3644 - accuracy: 0.8137 - balanced_accuracy: 0.8803
# Balanced Accuracy score is 0.8979832358350631

# %% [markdown]
# ### **Test Prediction and Submission**:
#
# This section includes the final test set prediction and save of the submission y_test file, as well as saving it's loss graph for later implementation for a Matlab graph (as seen in the final report).

# %%
print(x_test)
print(x_test.shape)

y_test = model_MLP.predict(x_test)
y_test = np.argmax(y_test, axis = 1)


print(y_test.shape)
print(y.shape)

np.save("ytest_Classification2.npy", y_test)
np.savetxt('x.txt', history.history['loss'], fmt='%f')
np.savetxt('y.txt', history.history['val_loss'], fmt='%f')

# %% [markdown]
# ## **Dual Branch Convolutional Neural Network**:
#
# This model is composed of three CNN's: the first one splits the original data into two subsets consisting of three classes each, where each subset serves to train their speacialized CNN model, thus providing better specifity in feature detection. However this implementation proved to be extremely similar in results to the already extremely optimised and developed single CNN for the six classes.

# %%
class_indices1 = np.where((y_train_balanced_shuffled == 0) | (y_train_balanced_shuffled == 1) | (y_train_balanced_shuffled == 2))
X_train_balanced_shuffled1 = X_train_balanced_shuffled[class_indices1]
y_train_balanced_c1 = y_train_balanced_shuffled[class_indices1]

class_indices2 = np.where((y_train_balanced_shuffled == 3) | (y_train_balanced_shuffled == 4) | (y_train_balanced_shuffled == 5))
X_train_balanced_shuffled2 = X_train_balanced_shuffled[class_indices2]
y_train_balanced_c2 = y_train_balanced_shuffled[class_indices2]

n_class1a = len([0 for i in range(y_train_balanced_c1.shape[0]) if y_train_balanced_c1[i] == 0])
n_class2a = len([0 for i in range(y_train_balanced_c1.shape[0]) if y_train_balanced_c1[i] == 1])
n_class3a = len([0 for i in range(y_train_balanced_c1.shape[0]) if y_train_balanced_c1[i] == 2])
n_class4a = len([0 for i in range(y_train_balanced_c1.shape[0]) if y_train_balanced_c1[i] == 3])
n_class5a = len([0 for i in range(y_train_balanced_c1.shape[0]) if y_train_balanced_c1[i] == 4])
n_class6a = len([0 for i in range(y_train_balanced_c1.shape[0]) if y_train_balanced_c1[i] == 5])

print(f'Class 1 is {(n_class1a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')
print(f'Class 2 is {(n_class2a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')
print(f'Class 3 is {(n_class3a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')
print(f'Class 4 is {(n_class4a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')
print(f'Class 5 is {(n_class5a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')
print(f'Class 6 is {(n_class6a/(n_class1a + n_class2a + n_class3a + n_class4a + n_class5a + n_class6a)) * 100}% of the balanced data set')

y_train_balanced_c1 = tf.keras.utils.to_categorical(y_train_balanced_c1,6)
y_train_balanced_c2 = tf.keras.utils.to_categorical(y_train_balanced_c2,6)

print(X_train_balanced_shuffled1.shape)
print(X_train_balanced_shuffled2.shape)
print(X_train_balanced_shuffled.shape)
print(y_train_balanced_c2.shape)
print(y_train_balanced_c1.shape)

class_indices1 = np.where((y_val == 0) | (y_val == 1) | (y_val == 2))
X_val1 = X_val[class_indices1]
y_val1  = y_val[class_indices1]

class_indices2 = np.where((y_val == 3) | (y_val == 4) | (y_val == 5))
X_val2 = X_val[class_indices2]
y_val2 = y_val[class_indices2]

y_val1 = tf.keras.utils.to_categorical(y_val1,6)
y_val2 = tf.keras.utils.to_categorical(y_val2,6)

print(f'X_train1 is : {X_train_balanced_shuffled1.shape}')
print(f'X_train2 is : {X_train_balanced_shuffled2.shape}')
print(f'X_val1 is : {X_val1.shape}')
print(f'X_val2 is : {X_val2.shape}')
print(f'y_train1 is : {y_train_balanced_c2.shape}')
print(f'y_train2 is : {y_train_balanced_c1.shape}')
print(f'y_val1 is : {y_val1.shape}')
print(f'y_val2 is : {y_val2.shape}')
print(y_train_balanced_c2.shape)
print(y_train_balanced_c1.shape)
# Out:
# Class 1 is 33.33333333333333% of the balanced data set
# Class 2 is 33.33333333333333% of the balanced data set
# Class 3 is 33.33333333333333% of the balanced data set
# Class 4 is 0.0% of the balanced data set
# Class 5 is 0.0% of the balanced data set
# Class 6 is 0.0% of the balanced data set
# (12867, 28, 28, 3)
# (12867, 28, 28, 3)
# (25734, 28, 28, 3)
# (12867, 6)
# (12867, 6)
# X_train1 is : (12867, 28, 28, 3)
# X_train2 is : (12867, 28, 28, 3)
# X_val1 is : (1274, 28, 28, 3)
# X_val2 is : (852, 28, 28, 3)
# y_train1 is : (12867, 6)
# y_train2 is : (12867, 6)
# y_val1 is : (1274, 6)
# y_val2 is : (852, 6)
# (12867, 6)
# (12867, 6)

# %%
y_train_first = y_train_balanced_shuffled
class_indices1 = np.where((y_train_first == 0) | (y_train_first == 1) | (y_train_first == 2))
y_train_first[class_indices1] = 0
class_indices2 = np.where((y_train_first == 3) | (y_train_first == 4) | (y_train_first == 5))
y_train_first[class_indices2] = 1  

y_val_first = y_val
class_indices1 = np.where((y_val_first == 0) | (y_val_first == 1) | (y_val_first == 2))
y_val_first[class_indices1] = 0
class_indices2 = np.where((y_val_first == 3) | (y_val_first == 4) | (y_val_first == 5))
y_val_first[class_indices2] = 1

y_train_first = tf.keras.utils.to_categorical(y_train_first,6)
y_val_first = tf.keras.utils.to_categorical(y_val_first,6)

# %%
batch_size = 500
lr = 0.001
epochs = 100

model_MLP = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(28, 28, 3)),
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.7),
    tf.keras.layers.Dense(6, activation='softmax')
])

model_MLP.summary()

adam = tf.keras.optimizers.Adam(learning_rate = lr)
model_MLP.compile(optimizer = adam,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy', balanced_accuracy])

early_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_balanced_accuracy', patience = 20, verbose = 1, restore_best_weights = True)

history = model_MLP.fit(x = X_train_balanced_shuffled, y = y_train_first, epochs = epochs, batch_size = batch_size, validation_data = (X_val,y_val_first), callbacks = [early_callback])



y_pred = model_MLP.predict(X_val)
y_pred = np.argmax(y_pred, axis = 1)
model_MLP.evaluate(X_val, y_val_first)
y_true = np.argmax(y_val_first, axis = 1)
print(f'Balanced Accuracy score is {balanced_accuracy_score(y_true, y_pred)}')


####PLOT EVOLUTION
plt.figure(1)
plt.clf()
plt.plot(history.history['loss'], label = 'train', color = "blue", linewidth = 3, alpha = 0.6)
plt.plot(history.history['val_loss'], label = 'validation', color = "green", linewidth = 3, alpha = 0.6)
plt.xlabel(r"Epochs")
plt.ylabel(r"Loss")
plt.title(r"CNN Evaluation", fontsize = 14)
plt.legend(labels=[r'Train', r'Validation'])
plt.grid(linestyle = '--', alpha = 0.5)
plt.show()

cm = confusion_matrix(y_true, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 26, 26, 32)        896
#
#  conv2d_21 (Conv2D)          (None, 24, 24, 32)        9248
#
#  conv2d_22 (Conv2D)          (None, 22, 22, 32)        9248
#
#  max_pooling2d_12 (MaxPoolin  (None, 11, 11, 32)       0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 11, 11, 32)        0
#
#  conv2d_23 (Conv2D)          (None, 9, 9, 64)          18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 4, 4, 64)          0
#
#  conv2d_24 (Conv2D)          (None, 2, 2, 128)         73856
#
#  max_pooling2d_14 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_4 (Flatten)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_9 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 120,646
# Trainable params: 120,518
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/100
# 52/52 [==============================] - 3s 29ms/step - loss: 0.5829 - accuracy: 0.8410 - balanced_accuracy: 0.8427 - val_loss: 1.0718 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 2/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0501 - accuracy: 0.9976 - balanced_accuracy: 0.9976 - val_loss: 0.5339 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 3/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0261 - accuracy: 0.9990 - balanced_accuracy: 0.9990 - val_loss: 0.2374 - val_accuracy: 0.9995 - val_balanced_accuracy: 0.9995
# Epoch 4/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0166 - accuracy: 0.9992 - balanced_accuracy: 0.9992 - val_loss: 0.1457 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 5/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0136 - accuracy: 0.9993 - balanced_accuracy: 0.9993 - val_loss: 0.0541 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 6/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0084 - accuracy: 0.9996 - balanced_accuracy: 0.9996 - val_loss: 0.0094 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 7/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0058 - accuracy: 0.9998 - balanced_accuracy: 0.9998 - val_loss: 0.0057 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 8/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0057 - accuracy: 0.9996 - balanced_accuracy: 0.9996 - val_loss: 0.0013 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 9/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0043 - accuracy: 0.9999 - balanced_accuracy: 0.9999 - val_loss: 8.6069e-04 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 10/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0220 - accuracy: 0.9965 - balanced_accuracy: 0.9965 - val_loss: 6.7595e-05 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 11/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0068 - accuracy: 0.9995 - balanced_accuracy: 0.9995 - val_loss: 2.0184e-04 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 12/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0031 - accuracy: 0.9998 - balanced_accuracy: 0.9999 - val_loss: 2.6628e-04 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 13/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0024 - accuracy: 1.0000 - balanced_accuracy: 1.0000 - val_loss: 2.8074e-04 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 14/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0044 - accuracy: 0.9995 - balanced_accuracy: 0.9995 - val_loss: 1.8071e-04 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 15/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0021 - accuracy: 0.9999 - balanced_accuracy: 0.9999 - val_loss: 1.5185e-04 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 16/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0018 - accuracy: 1.0000 - balanced_accuracy: 1.0000 - val_loss: 1.0125e-04 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 17/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0016 - accuracy: 0.9999 - balanced_accuracy: 0.9999 - val_loss: 1.2691e-04 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 18/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0015 - accuracy: 0.9999 - balanced_accuracy: 0.9999 - val_loss: 1.0993e-04 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 19/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0013 - accuracy: 1.0000 - balanced_accuracy: 1.0000 - val_loss: 7.3786e-05 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 20/100
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0018 - accuracy: 0.9999 - balanced_accuracy: 0.9999 - val_loss: 1.0078e-04 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 21/100
# 52/52 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999 - balanced_accuracy: 0.9999Restoring model weights from the end of the best epoch: 1.
# 52/52 [==============================] - 1s 23ms/step - loss: 0.0011 - accuracy: 0.9999 - balanced_accuracy: 0.9999 - val_loss: 5.9935e-05 - val_accuracy: 1.0000 - val_balanced_accuracy: 1.0000
# Epoch 21: early stopping
# 67/67 [==============================] - 0s 5ms/step - loss: 1.0718 - accuracy: 1.0000 - balanced_accuracy: 1.0000
# Balanced Accuracy score is 1.0

# %%
batch_size = 1000
lr = 0.001
epochs = 100

model_MLP = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(28, 28, 3)),
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.7),
    tf.keras.layers.Dense(6, activation='softmax')
])

model_MLP.summary()

adam = tf.keras.optimizers.Adam(learning_rate = lr)
model_MLP.compile(optimizer = adam,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy', balanced_accuracy])

early_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_balanced_accuracy', patience = 20, verbose = 1, restore_best_weights = True)

history = model_MLP.fit(x = X_train_balanced_shuffled1, y = y_train_balanced_c1, epochs = epochs, batch_size = batch_size, validation_data = (X_val1,y_val1), callbacks = [early_callback])


y_pred = model_MLP.predict(X_val1)
y_pred = np.argmax(y_pred, axis = 1)
first_output = y_pred
model_MLP.evaluate(X_val1, y_val1)
y_true = np.argmax(y_val1, axis = 1)
print(f'Balanced Accuracy score is {balanced_accuracy_score(y_true, y_pred)}')


####PLOT EVOLUTION
plt.figure(1)
plt.clf()
plt.plot(history.history['loss'], label = 'train', color = "blue", linewidth = 3, alpha = 0.6)
plt.plot(history.history['val_loss'], label = 'validation', color = "green", linewidth = 3, alpha = 0.6)
plt.xlabel(r"Epochs")
plt.ylabel(r"Loss")
plt.title(r"CNN Evaluation", fontsize = 14)
plt.legend(labels=[r'Train', r'Validation'])
plt.grid(linestyle = '--', alpha = 0.5)
plt.show()

cm = confusion_matrix(y_true, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 26, 26, 32)        896
#
#  conv2d_31 (Conv2D)          (None, 24, 24, 32)        9248
#
#  conv2d_32 (Conv2D)          (None, 22, 22, 32)        9248
#
#  max_pooling2d_18 (MaxPoolin  (None, 11, 11, 32)       0
#  g2D)
#
#  dropout_24 (Dropout)        (None, 11, 11, 32)        0
#
#  conv2d_33 (Conv2D)          (None, 9, 9, 64)          18496
#
#  max_pooling2d_19 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  dropout_25 (Dropout)        (None, 4, 4, 64)          0
#
#  conv2d_34 (Conv2D)          (None, 2, 2, 128)         73856
#
#  max_pooling2d_20 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_26 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_6 (Flatten)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_27 (Dropout)        (None, 64)                0
#
#  dense_13 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 120,646
# Trainable params: 120,518
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 1s 57ms/step - loss: 1.8104 - accuracy: 0.3027 - balanced_accuracy: 0.3046 - val_loss: 1.7313 - val_accuracy: 0.5078 - val_balanced_accuracy: 0.5223
# Epoch 2/100
# 13/13 [==============================] - 1s 41ms/step - loss: 1.3664 - accuracy: 0.5217 - balanced_accuracy: 0.5225 - val_loss: 1.6604 - val_accuracy: 0.5235 - val_balanced_accuracy: 0.5966
# Epoch 3/100
# 13/13 [==============================] - 1s 41ms/step - loss: 1.1040 - accuracy: 0.6311 - balanced_accuracy: 0.6324 - val_loss: 1.5705 - val_accuracy: 0.5769 - val_balanced_accuracy: 0.7532
# Epoch 4/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.9207 - accuracy: 0.7033 - balanced_accuracy: 0.7038 - val_loss: 1.5281 - val_accuracy: 0.4239 - val_balanced_accuracy: 0.7190
# Epoch 5/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0
100
# 13/13 [==============================] - ETA: 0s - loss: 0.2618 - accuracy: 0.8869 - balanced_accuracy: 0.8867Restoring model weights from the end of the best epoch: 37.
# 13/13 [==============================] - 1s 42ms/step - loss: 0.2618 - accuracy: 0.8869 - balanced_accuracy: 0.8867 - val_loss: 0.4202 - val_accuracy: 0.7567 - val_balanced_accuracy: 0.8077
# Epoch 57: early stopping
# 40/40 [==============================] - 0s 6ms/step - loss: 0.4570 - accuracy: 0.7520 - balanced_accuracy: 0.8413
# Balanced Accuracy score is 0.8484766119824995

# %%
batch_size = 1000
lr = 0.001
epochs = 100

model_MLP = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(28, 28, 3)),
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=2),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.7),
    tf.keras.layers.Dense(6, activation='softmax')
])

model_MLP.summary()

adam = tf.keras.optimizers.Adam(learning_rate = lr)
model_MLP.compile(optimizer = adam,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy', balanced_accuracy])

early_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_balanced_accuracy', patience = 20, verbose = 1, restore_best_weights = True)

history = model_MLP.fit(x = X_train_balanced_shuffled2, y = y_train_balanced_c2, epochs = epochs, batch_size = batch_size, validation_data = (X_val2,y_val2), callbacks = [early_callback])

y_pred = model_MLP.predict(X_val2)
y_pred = np.argmax(y_pred, axis = 1)
second_output = y_pred
model_MLP.evaluate(X_val2, y_val2)
y_true = np.argmax(y_val2, axis = 1)
print(f'Balanced Accuracy score is {balanced_accuracy_score(y_true, y_pred)}')


####PLOT EVOLUTION
plt.figure(1)
plt.clf()
plt.plot(history.history['loss'], label = 'train', color = "blue", linewidth = 3, alpha = 0.6)
plt.plot(history.history['val_loss'], label = 'validation', color = "green", linewidth = 3, alpha = 0.6)
plt.xlabel(r"Epochs")
plt.ylabel(r"Loss")
plt.title(r"CNN Evaluation", fontsize = 14)
plt.legend(labels=[r'Train', r'Validation'])
plt.grid(linestyle = '--', alpha = 0.5)
plt.show()

cm = confusion_matrix(y_true, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_50 (Conv2D)          (None, 26, 26, 32)        896
#
#  conv2d_51 (Conv2D)          (None, 24, 24, 32)        9248
#
#  conv2d_52 (Conv2D)          (None, 22, 22, 32)        9248
#
#  max_pooling2d_30 (MaxPoolin  (None, 11, 11, 32)       0
#  g2D)
#
#  dropout_40 (Dropout)        (None, 11, 11, 32)        0
#
#  conv2d_53 (Conv2D)          (None, 9, 9, 64)          18496
#
#  max_pooling2d_31 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  dropout_41 (Dropout)        (None, 4, 4, 64)          0
#
#  conv2d_54 (Conv2D)          (None, 2, 2, 128)         73856
#
#  max_pooling2d_32 (MaxPoolin  (None, 1, 1, 128)        0
#  g2D)
#
#  dropout_42 (Dropout)        (None, 1, 1, 128)         0
#
#  flatten_10 (Flatten)        (None, 128)               0
#
#  dense_20 (Dense)            (None, 64)                8256
#
#  batch_normalization_10 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_43 (Dropout)        (None, 64)                0
#
#  dense_21 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 120,646
# Trainable params: 120,518
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] -
100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.3301 - accuracy: 0.8969 - balanced_accuracy: 0.8971 - val_loss: 0.8016 - val_accuracy: 0.8838 - val_balanced_accuracy: 0.8639
# Epoch 19/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.3114 - accuracy: 0.9001 - balanced_accuracy: 0.9005 - val_loss: 0.7705 - val_accuracy: 0.8791 - val_balanced_accuracy: 0.8716
# Epoch 20/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.2928 - accuracy: 0.9039 - balanced_accuracy: 0.9044 - val_loss: 0.7406 - val_accuracy: 0.8873 - val_balanced_accuracy: 0.8642
# Epoch 21/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.2901 - accuracy: 0.9043 - balanced_accuracy: 0.9045 - val_loss: 0.7111 - val_accuracy: 0.8779 - val_balanced_accuracy: 0.8629
# Epoch 22/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.2831 - accuracy: 0.9081 - balanced_accuracy: 0.9081 - val_loss: 0.6988 - val_accuracy: 0.8932 - val_balanced_accuracy: 0.8795
# Epoch 23/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.2730 - accuracy: 0.9140 - balanced_accuracy: 0.9139 - val_loss: 0.6360 - val_accuracy: 0.8779 - val_balanced_accuracy: 0.8417
# Epoch 24/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.2689 - accuracy: 0.9111 - balanced_accuracy: 0.9117 - val_loss: 0.6235 - val_accuracy: 0.9026 - val_balanced_accuracy: 0.8881
# Epoch 25/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.2695 - accuracy: 0.9105 - balanced_accuracy: 0.9108 - val_loss: 0.6120 - val_accuracy: 0.9014 - val_balanced_accuracy: 0.8730
# Epoch 26/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.2584 - accuracy: 0.9156 - balanced_accuracy: 0.9158 - val_loss: 0.5614 - val_accuracy: 0.8838 - val_balanced_accuracy: 0.8726
# Epoch 27/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.2469 - accuracy: 0.9180 - balanced_accuracy: 0.9182 - val_loss: 0.5000 - val_accuracy: 0.9249 - val_balanced_accuracy: 0.9123
# Epoch 28/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.2289 - accuracy: 0.9245 - balanced_accuracy: 0.9245 - val_loss: 0.4226 - val_accuracy: 0.9237 - val_balanced_accuracy: 0.9021
# Epoch 29/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.2277 - accuracy: 0.9272 - balanced_accuracy: 0.9275 - val_loss: 0.4755 - val_accuracy: 0.9096 - val_balanced_accuracy: 0.9064
# Epoch 30/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.2170 - accuracy: 0.9287 - balanced_accuracy: 0.9287 - val_loss: 0.4596 - val_accuracy: 0.8756 - val_balanced_accuracy: 0.8852
# Epoch 31/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.2145 - accuracy: 0.9288 - balanced_accuracy: 0.9290 - val_loss: 0.3395 - val_accuracy: 0.9507 - val_balanced_accuracy: 0.9424
# Epoch 32/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.2114 - accuracy: 0.9316 - balanced_accuracy: 0.9318 - val_loss: 0.4038 - val_accuracy: 0.9131 - val_balanced_accuracy: 0.8946
# Epoch 33/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.2070 - accuracy: 0.9352 - balanced_accuracy: 0.9353 - val_loss: 0.3501 - val_accuracy: 0.9155 - val_balanced_accuracy: 0.8801
# Epoch 34/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.2115 - accuracy: 0.9294 - balanced_accuracy: 0.9298 - val_loss: 0.3523 - val_accuracy: 0.9002 - val_balanced_accuracy: 0.8635
# Epoch 35/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.1997 - accuracy: 0.9337 - balanced_accuracy: 0.9337 - val_loss: 0.2705 - val_accuracy: 0.9484 - val_balanced_accuracy: 0.9447
# Epoch 36/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1871 - accuracy: 0.9398 - balanced_accuracy: 0.9400 - val_loss: 0.3976 - val_accuracy: 0.8697 - val_balanced_accuracy: 0.8586
# Epoch 37/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1907 - accuracy: 0.9365 - balanced_accuracy: 0.9365 - val_loss: 0.3925 - val_accuracy: 0.8638 - val_balanced_accuracy: 0.8560
# Epoch 38/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1879 - accuracy: 0.9388 - balanced_accuracy: 0.9392 - val_loss: 0.2158 - val_accuracy: 0.9507 - val_balanced_accuracy: 0.9431
# Epoch 39/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1728 - accuracy: 0.9423 - balanced_accuracy: 0.9423 - val_loss: 0.1809 - val_accuracy: 0.9613 - val_balanced_accuracy: 0.9585
# Epoch 40/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1630 - accuracy: 0.9454 - balanced_accuracy: 0.9456 - val_loss: 0.2127 - val_accuracy: 0.9354 - val_balanced_accuracy: 0.9393
# Epoch 41/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1653 - accuracy: 0.9479 - balanced_accuracy: 0.9480 - val_loss: 0.1931 - val_accuracy: 0.9448 - val_balanced_accuracy: 0.9472
# Epoch 42/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1623 - accuracy: 0.9481 - balanced_accuracy: 0.9482 - val_loss: 0.2371 - val_accuracy: 0.9202 - val_balanced_accuracy: 0.9228
# Epoch 43/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1570 - accuracy: 0.9499 - balanced_accuracy: 0.9501 - val_loss: 0.2072 - val_accuracy: 0.9202 - val_balanced_accuracy: 0.9349
# Epoch 44/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1764 - accuracy: 0.9424 - balanced_accuracy: 0.9427 - val_loss: 0.2913 - val_accuracy: 0.8779 - val_balanced_accuracy: 0.9038
# Epoch 45/100
# 13/13 [==============================] - 1s 42ms/step - loss: 0.1641 - accuracy: 0.9456 - balanced_accuracy: 0.9460 - val_loss: 0.1703 - val_accuracy: 0.9401 - val_balanced_accuracy: 0.9452
# Epoch 46/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1544 - accuracy: 0.9489 - balanced_accuracy: 0.9490 - val_loss: 0.1435 - val_accuracy: 0.9566 - val_balanced_accuracy: 0.9497
# Epoch 47/100
# 13/13 [==============================] - 0s 39ms/step - loss: 0.1501 - accuracy: 0.9506 - balanced_accuracy: 0.9509 - val_loss: 0.1647 - val_accuracy: 0.9484 - val_balanced_accuracy: 0.9386
# Epoch 48/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1593 - accuracy: 0.9485 - balanced_accuracy: 0.9488 - val_loss: 0.1501 - val_accuracy: 0.9495 - val_balanced_accuracy: 0.9444
# Epoch 49/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1541 - accuracy: 0.9513 - balanced_accuracy: 0.9519 - val_loss: 0.1244 - val_accuracy: 0.9531 - val_balanced_accuracy: 0.9564
# Epoch 50/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1480 - accuracy: 0.9506 - balanced_accuracy: 0.9509 - val_loss: 0.1960 - val_accuracy: 0.9272 - val_balanced_accuracy: 0.9402
# Epoch 51/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1355 - accuracy: 0.9543 - balanced_accuracy: 0.9544 - val_loss: 0.1366 - val_accuracy: 0.9472 - val_balanced_accuracy: 0.9438
# Epoch 52/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.1520 - accuracy: 0.9493 - balanced_accuracy: 0.9495 - val_loss: 0.1211 - val_accuracy: 0.9542 - val_balanced_accuracy: 0.9590
# Epoch 53/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1423 - accuracy: 0.9538 - balanced_accuracy: 0.9543 - val_loss: 0.1939 - val_accuracy: 0.9225 - val_balanced_accuracy: 0.9174
# Epoch 54/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.
100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1089 - accuracy: 0.9643 - balanced_accuracy: 0.9644 - val_loss: 0.1501 - val_accuracy: 0.9472 - val_balanced_accuracy: 0.9416
# Epoch 73/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1050 - accuracy: 0.9653 - balanced_accuracy: 0.9654 - val_loss: 0.1734 - val_accuracy: 0.9425 - val_balanced_accuracy: 0.9278
# Epoch 74/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.1106 - accuracy: 0.9635 - balanced_accuracy: 0.9639 - val_loss: 0.1257 - val_accuracy: 0.9531 - val_balanced_accuracy: 0.9552
# Epoch 75/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1003 - accuracy: 0.9667 - balanced_accuracy: 0.9670 - val_loss: 0.1433 - val_accuracy: 0.9460 - val_balanced_accuracy: 0.9459
# Epoch 76/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0979 - accuracy: 0.9676 - balanced_accuracy: 0.9677 - val_loss: 0.1274 - val_accuracy: 0.9519 - val_balanced_accuracy: 0.9477
# Epoch 77/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1026 - accuracy: 0.9654 - balanced_accuracy: 0.9658 - val_loss: 0.1081 - val_accuracy: 0.9566 - val_balanced_accuracy: 0.9576
# Epoch 78/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0979 - accuracy: 0.9676 - balanced_accuracy: 0.9678 - val_loss: 0.1102 - val_accuracy: 0.9542 - val_balanced_accuracy: 0.9445
# Epoch 79/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1069 - accuracy: 0.9652 - balanced_accuracy: 0.9653 - val_loss: 0.1044 - val_accuracy: 0.9495 - val_balanced_accuracy: 0.9494
# Epoch 80/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.1049 - accuracy: 0.9650 - balanced_accuracy: 0.9651 - val_loss: 0.1066 - val_accuracy: 0.9589 - val_balanced_accuracy: 0.9522
# Epoch 81/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.1123 - accuracy: 0.9624 - balanced_accuracy: 0.9627 - val_loss: 0.1656 - val_accuracy: 0.9401 - val_balanced_accuracy: 0.9333
# Epoch 82/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0933 - accuracy: 0.9695 - balanced_accuracy: 0.9697 - val_loss: 0.1350 - val_accuracy: 0.9507 - val_balanced_accuracy: 0.9528
# Epoch 83/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 0.9659 - balanced_accuracy: 0.9662Restoring model weights from the end of the best epoch: 63.
# 13/13 [==============================] - 1s 41ms/step - loss: 0.1047 - accuracy: 0.9659 - balanced_accuracy: 0.9662 - val_loss: 0.1175 - val_accuracy: 0.9554 - val_balanced_accuracy: 0.9519
# Epoch 83: early stopping
# 27/27 [==============================] - 0s 7ms/step - loss: 0.1044 - accuracy: 0.9601 - balanced_accuracy: 0.9646
# Balanced Accuracy score is 0.9607039263339489

# %%
output_pred = np.concatenate((first_output, second_output), axis = 0)

print(output_pred.shape)
print(output_pred.shape)

output = np.concatenate((y_val1, y_val2), axis = 0)
output = np.argmax(output, axis = 1)

print(f'Balanced Accuracy score is {balanced_accuracy_score(output, output_pred)}')
# Out:
# (2126,)
# (2126,)
# Balanced Accuracy score is 0.904590269158224

# %% [markdown]
# ## **Random Forest**:
#
# A model that composes multiple self-learning decision trees, also forming their own ensemble, due to pooling and comparing the different results provided by each decision tree. However, due to the nature of image classification, this model performs slightly worse than SVM

# %%
import tensorflow_decision_forests as tfdf

x_v = np.load("Xtrain_Classification2.npy")
y_v = np.load("ytrain_Classification2.npy")

x_v = (x_v).astype('float32')/255.0

X_train_v, X_val_v, y_train_v, y_val_v = train_test_split(x_v, y_v, stratify = y,test_size = 0.2)

model_1 = tfdf.keras.RandomForestModel(verbose=2)

model_1.fit(X_train_v, y_train_v)

model_1.compile(metrics=["accuracy", balanced_accuracy])
evaluation = model_1.evaluate(X_val_v, y_val_v, return_dict=True)
print()

for name, value in evaluation.items():
  print(f"{name}: {value:.4f}")

# %% [markdown]
# ## **Transfer Learning**:
#
# To display results provided by an extremely complex feature identification section, transfer learning is as good as it gets. However it's lack of especifity and blurred images due to resize requirements make it lag behind the home-made developed CNN's.

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3


X_train_tl = tf.image.resize(X_train_balanced_shuffled, (150,150))

plt.figure(figsize=(10, 10))
for i in range(100):
    ax = plt.subplot(10, 10, i + 1)
    plt.imshow(X_train_tl[i])
    plt.axis("off")

# %%
X_val_tl = tf.image.resize(X_val, (150,150))

base_model = InceptionV3(input_shape = (150, 150, 3), include_top = False, weights = 'imagenet')


for layer in base_model.layers:
    layer.trainable = False

x = tf.keras.layers.Flatten()(base_model.output)
x = tf.keras.layers.Dense(1024, activation='relu')(x)
x = tf.keras.layers.Dropout(0.2)(x)

x = tf.keras.layers.Dense(6, activation='softmax')(x)

model = tf.keras.models.Model(base_model.input, x)

adam = tf.keras.optimizers.Adam(learning_rate = 0.001)


model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])

early_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 20, verbose = 1, restore_best_weights = True)

tl_history = model.fit(x = X_train_tl, y = y_train_balanced_c, validation_data = (X_val_tl,y_val_c), epochs = 10, batch_size = 1000, callbacks = [early_callback])

# %%
y_true = y_val_c
y_pred = model.predict(X_val_tl)
model.evaluate(X_val_tl, y_val_c)
print(f'Balanced Accuracy score is {balanced_accuracy_score(y_true, y_pred)}')


plt.figure(1)
plt.clf()
plt.plot(tl_history.history['loss'], label = 'train', color = "blue", linewidth = 3, alpha = 0.6)
plt.plot(tl_history.history['val_loss'], label = 'validation', color = "green", linewidth = 3, alpha = 0.6)
plt.xlabel(r"Epochs")
plt.ylabel(r"Loss")
plt.title(r"CNN Evaluation - Transfer Learning", fontsize = 14)
plt.legend(labels=[r'Train', r'Validation'])
plt.grid(linestyle = '--', alpha = 0.5)
plt.show()

cm_tl = confusion_matrix(y_true, y_pred)
cm_display = ConfusionMatrixDisplay(cm_tl).plot()

# %% [markdown]
# ## **SVM Image Classification**:
#
# An image classification model was also tested in the form of Support Vector Classifier (SVC for short), in order to be able to provide an apt comparison to the developed CNN.

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)

svm_x = np.load("Xtrain_Classification2.npy")
svm_y = np.load("ytrain_Classification2.npy")

svm_X_train, svm_X_val, svm_y_train, svm_y_val = train_test_split(svm_x, svm_y, test_size = 0.2)
svm_X_train, svm_y_train = rus.fit_resample(svm_X_train, svm_y_train)

print(svm_X_train.shape, svm_y_train.shape, svm_X_val.shape, svm_y_val.shape)
unique, counts = np.unique(svm_y_train, return_counts=True)
print(dict(zip(unique, counts)))

# %%
from sklearn.svm import SVC


svm_classifier = SVC(kernel='linear', C=1, random_state=42)


svm_classifier.fit(svm_X_train, svm_y_train)
y_predi = svm_classifier.predict(svm_X_val)

balanced_accuracy = balanced_accuracy_score(svm_y_val, y_predi)
print("Balanced Accuracy Score:", balanced_accuracy)
